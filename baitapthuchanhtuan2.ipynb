# %%
#W2A1
print('Hello World!')
# Out:
# Hello World!

# %%
#W2A2
name = input('name:')
print('Hello', name)
# Out:
# Hello Ronaldo

# %%
#W2A3
a,b = map(int,input('a,b=').split())
print('Tổng =',a+b)
print('Hiệu =',a-b)
print('Tích =',a*b)
print('Phần nguyên khi chia =',a//b)
print('Phần dư =',a%b)
n=a/b
print('Chia thực làm tròn 2 chữ số:','%.2f'%n)
# Out:
# Tổng = 105
# Hiệu = -33
# Tích = 2484
# Phần nguyên khi chia = 0
# Phần dư = 36
# Chia thực làm tròn 2 chữ số: 0.52

# %%
#W2A4
a1,b1,c1,a2,b2,a3 = map(float,input('Nhập điểm vào đây:').split())
TB = ((a1+b1+c1)+(a2+b2)*2+a3*3)/10
print('Điểm trung bình môn học của 6 môn học:','%.1f'%TB)
# Out:
# Điểm trung bình môn học của 6 môn học: 6.8

# %%
#W2A5
a,b = map(int,input('a,b=').split())
print(a**b)
# Out:
# 338464177770582700867528197630612812643411481076411271352964279330592074344897475465841485100167185056251698842680702037916169590222050610365414966035295777475786702161805297281

# %%
#W2A6
a=input('Nhập a vào đây:')
print(chr(ord(a)-32))
# Out:
# A

# %%
#W2A7
A,B = ((13 ** 2) * 3),  13**2*3 + 5
print(A,B,sep='=')
# Out:
# 507=512

# %%
#W2A8 
C = float(input('Nhập cmm vào đây:'))
F = (9/5)*C+32
print('%.2f'%F)
# Out:
# 96.80

# %%
#W2A9
x = int(input(''))
x_2 = x + 10 + x*0.3 + x*0.1
print('Số tiền phải trả:','%.2f'%x_2 )
# Out:
# Số tiền phải trả: 60.40

# %%
#W2A10
a,b,c = map(str,input().split())
print('Hi',c+',',b,'and',a)

# %%
#W2A11
def second(a,b):
    n = a*3600 + b*60
    return n
a,b = map(int,input('').split())
print(second(a,b))

# %%
#W2A12
n = int(input())
print((n**n)*6)

# %%
#W2A13
def hoandoi(a,b):
    n,p = b, a
    return n,p
)
