# %% [markdown]
# Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diệntíchvàchu vi của nó.

# %%
chieudai, chieurong = map(float, input('Nhập chiều dài và chiều rộng lần lượt vào đây:').split())
print('Diện tích hình chữ nhật:', chieudai * chieurong)
print('Chu vi hình chữ nhật:', 2 * (chieudai + chieurong))
# Out:
# Diện tích hình chữ nhật: 6.0
# Chu vi hình chữ nhật: 10.0

# %% [markdown]
# Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
R = float(input(' Nhập vào bán kính của hình tròn:'))
print('Diện tích hình tròn:', 3.14 * (R**2))
print('Chu vi hình tròn:', 2 * 3.14 * R)
# Out:
# Diện tích hình tròn: 28.26
# Chu vi hình tròn: 18.84

# %% [markdown]
# Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra màn hình.

# %%
a, b, c = map(float, input('Nhập 3 cạnh của tam giác vào đây:').split())
if (a > 0) and (b > 0) and (c > 0) and ((a + b) > c) and ((a + c) > b) and ((b + c) > a):
    if (a == b) and (a == c) and (b == c):
        print('Đây là tam giác đều')
    elif (a == b) or (b == c) or (a == c):
        print('Đây là tam giác cân')
    elif (((a ** 2) + (b **2)) == (c ** 2)) or (((a ** 2) + (c ** 2)) == (b ** 2)) or (((b ** 2) + (c ** 2)) == (a ** 2)):
        print('Đây là tam giác vuông')
    else:
        print('Đây là tam giác thường')
else:
    print('Đây không phải tam giác')
# Out:
# Đây là tam giác vuông

# %% [markdown]
# Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a, b = map(float, input('Nhập a và b tương ứng với hệ số góc và điều kiện ban đầu của phương trình:').split())
if a == 0:
    if b == 0:
        print('Vô số nghiệm')
    else:
        print('Vô nghiệm')
else:
    x = ((-1) * b) / a
    print('Nghiệm của phương trình ax+b=0:', x)
# Out:
# Vô nghiệm

# %% [markdown]
# Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a, b, c = map(int, input('Nhập 3 số a, b, c tương ứng là các hệ số trong phương trình ax^2 + bx +c = 0:').split())
delta = (b**2) - (4*a*c)
if delta > 0:
    print('Phương trình có 2 nghiệm phân biệt lần lượt là:', (-b + delta**(1/2))/(2*a), (-b - delta**(1/2))/(2*a))
elif delta == 0:
    print('Phương trình có 1 nghiệm kép:', -b/(2*a))
else:
    print('Phương trình vô nghiệm')

# %% [markdown]
# Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím).

# %%
a, b, c, d = map(float, input().split())
#Cách 1:
if (a > b) and (a > c) and (a > d):
    print(f'{a} là giá trị lớn nhất')
elif (b > a) and (b > c) and (b > d):
    print(f'{b} là giá trị lớn nhất')
elif (c > a) and (c > b) and (c > d):
    print(f'{c} là giá trị lớn nhất')
else:
    print(f'{d} là giá trị lớn nhất')
#Cách 2:
# N = max(a, b, c, d) -----> print(N)
# Out:
# 69.0 là giá trị lớn nhất

# %% [markdown]
# Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím).

# %%
a, b, c, d = map(float, input().split())
#Cách 1:
if (a < b) and (a < c) and (a < d):
    print(f'{a} là giá trị nhỏ nhất')
elif (b < a) and (b < c) and (b < d):
    print(f'{b} là giá trị nhỏ nhất')
elif (c < a) and (c < b) and (c < d):
    print(f'{c} là giá trị nhỏ nhất')
else:
    print(f'{d} là giá trị nhỏ nhất')
# Out:
# 1.0 là giá trị nhỏ nhất

# %% [markdown]
# Bài 8: Giải hệ phương trình tuyến tính:
# ax  by  m
# cx  dy  n

# %%
a, b, c, d, m ,n = map(int, input().split())
#Giải phương trình theo phương pháp hạng ma trận
#Các hệ số a, b, m ở hàng 1 còn c, d, n ở hàng 2
#Lấy hàng 1 làm mốc và biến đổi hàng 2 sao cho ma trận A và ma trận A ngang về dạng bậc thang
c2, d2, n2 = ((-c/a)*a) + c, ((-c/a)*b) + d, ((-c/a)*m) + n #Ta được hệ số phương trình số 2 mới
if ((d2 == 0) and (n2 != 0)) or ((d2 != 0) and (n2 == 0)): #rank(A) khác rank(A ngang)
    print('Hệ phương trình vô nghiệm')
else: 
    if (d2 == 0) and (n2 == 0): #rank(A) = rank(A ngang) < 2
        print('Hệ phương trình vô số nghiệm')
    else: #rank(A) = rank(A ngang) = 2
        y = n2 / d2
        x = ((m - ((b*n2)/d2))/a)
        print('Nghiệm x, y  của phương trình lần lượt là:',x, y)
# Out:
# Vô số nghiệm

# %% [markdown]
# Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %%
x = int(input('Nhập số giây vào đây:'))
n1, n2, n3 = x // 3600, (x % 3600) // 60, (x % 3600) % 60
print(f'{x} giây viết dưới dạng giờ, phút, giây là {n1} giờ {n2} phút {n3} giây')

# %% [markdown]
# Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vàomộtđiểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
x0, y0, R, x, y = map(int, input('Tọa độ của tâm S(x0,y0), bán kính R, và tọa độ điểm A(x,y):').split())
if (x-x0)**2 + (y-y0)**2 == R**2:
    print(f'Điểm A({x},{y}) thuộc đường tròn tâm S({x0},{y0}), bán kính bằng {R}')
else:
    print(f'Điểm A({x},{y}) không thuộc đường tròn tâm S({x0},{y0}), bán kính bằng {R}')
# Out:
# Điểm A(2,1) không thuộc đường tròn tâm S(0,0), bán kính bằng 2

# %% [markdown]
# Bài 11: Tính x^y (Với x, y là số thực).

# %%
x, y = map(float, input().split())
print (x**y)
